# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
Data = pd.read_excel("C:/Users/nxt-1/Desktop/Dataset/laptopData_after_cleaning.xlsx")

# %%
Data.set_index("Labtop_ID")
# Out:
#           Company            TypeName  Inches  \
# Labtop_ID
# 0.0         Apple           Ultrabook    13.3
# 1.0         Apple           Ultrabook    13.3
# 2.0            HP            Notebook    15.6
# 3.0         Apple           Ultrabook    15.4
# 4.0         Apple           Ultrabook    13.3
# ...           ...                 ...     ...
# 1298.0     Lenovo  2 in 1 Convertible    14.0
# 1299.0     Lenovo  2 in 1 Convertible    13.3
# 1300.0     Lenovo            Notebook    14.0
# 1301.0         HP            Notebook    15.6
# 1302.0       Asus            Notebook    15.6
#
#                                      ScreenResolution  \
# Labtop_ID
# 0.0                IPS Panel Retina Display 2560x1600
# 1.0                                          1440x900
# 2.0                                 Full HD 1920x1080
# 3.0                IPS Panel Retina Display 2880x1800
# 4.0                IPS Panel Retina Display 2560x1600
# ...                                               ...
# 1298.0      IPS Panel Full HD / Touchscreen 1920x1080
# 1299.0     IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300.0                                       1366x768
# 1301.0                                       1366x768
# 1302.0                                       1366x768
#
#                                             Cpu   Ram               Memory  \
# Labtop_ID
# 0.0                        Intel Core i5 2.3GHz   8.0            128GB SSD
# 1.0                        Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2.0                  Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3.0                        Intel Core i7 2.7GHz  16.0            512GB SSD
# 4.0                        Intel Core i5 3.1GHz   8.0            256GB SSD
# ...                                         ...   ...                  ...
# 1298.0               Intel Core i7 6500U 2.5GHz   4.0            128GB SSD
# 1299.0               Intel Core i7 6500U 2.5GHz  16.0            512GB SSD
# 1300.0     Intel Celeron Dual Core N3050 1.6GHz   2.0   64GB Flash Storage
# 1301.0               Intel Core i7 6500U 2.5GHz   6.0              1TB HDD
# 1302.0     Intel Celeron Dual Core N3050 1.6GHz   4.0            500GB HDD
#
#                                     Gpu       OpSys  Weight        Price
# Labtop_ID
# 0.0        Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1.0              Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2.0               Intel HD Graphics 620       No OS    1.86   30636.0000
# 3.0                  AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4.0        Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                                 ...         ...     ...          ...
# 1298.0            Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299.0            Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300.0                Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301.0               AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302.0                Intel HD Graphics  Windows 10    2.20   19660.3200
#
# [1303 rows x 11 columns]

# %%
Data.isnull().sum()
# Out:
# Labtop_ID           30
# Company             30
# TypeName            30
# Inches              31
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              31
# Price               30
# dtype: int64

# %%
Data.dropna(inplace=True)

# %%
Data["Company"].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
Label = preprocessing.LabelEncoder()

# %%
Lable_Company = Label.fit_transform(Data["Company"])
Lable_TypeName = Label.fit_transform(Data["TypeName"])
Lable_OpSys = Label.fit_transform(Data["OpSys"])

# %%
Data ["Lable_Company"] = Lable_Company
Data["Lable_OpSys"] = Lable_OpSys
Data["Lable_TypeName"] = Lable_TypeName

# %%
Data.head(20)
# Out:
#     Labtop_ID Company   TypeName  Inches  \
# 0         0.0   Apple  Ultrabook    13.3
# 1         1.0   Apple  Ultrabook    13.3
# 2         2.0      HP   Notebook    15.6
# 3         3.0   Apple  Ultrabook    15.4
# 4         4.0   Apple  Ultrabook    13.3
# 5         5.0    Acer   Notebook    15.6
# 6         6.0   Apple  Ultrabook    15.4
# 7         7.0   Apple  Ultrabook    13.3
# 8         8.0    Asus  Ultrabook    14.0
# 9         9.0    Acer  Ultrabook    14.0
# 10       10.0      HP   Notebook    15.6
# 11       11.0      HP   Notebook    15.6
# 12       12.0   Apple  Ultrabook    15.4
# 13       13.0    Dell   Notebook    15.6
# 14       14.0   Apple  Ultrabook    12.0
# 15       15.0   Apple  Ultrabook    13.3
# 16       16.0    Dell   Notebook    15.6
# 17       17.0   Apple  Ultrabook    15.4
# 18       18.0  Lenovo   Notebook    15.6
# 19       19.0    Dell  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# 0          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1                                    1440x900        Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 3          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 4          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# 5                                    1366x768     AMD A9-Series 9420 3GHz
# 6          IPS Panel Retina Display 2880x1800        Intel Core i7 2.2GHz
# 7                                    1440x900        Intel Core i5 1.8GHz
# 8                           Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 9                 IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 10                                   1366x768  Intel Core i5 7200U 2.5GHz
# 11                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 12         IPS Panel Retina Display 2880x1800        Intel Core i7 2.8GHz
# 13                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 14         IPS Panel Retina Display 2304x1440      Intel Core M m3 1.2GHz
# 15         IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 16                          Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 17         IPS Panel Retina Display 2880x1800        Intel Core i7 2.9GHz
# 18                          Full HD 1920x1080  Intel Core i3 7100U 2.4GHz
# 19  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
#
#      Ram               Memory                           Gpu       OpSys  \
# 0    8.0            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1    8.0  128GB Flash Storage        Intel HD Graphics 6000       macOS
# 2    8.0            256GB SSD         Intel HD Graphics 620       No OS
# 3   16.0            512GB SSD            AMD Radeon Pro 455       macOS
# 4    8.0            256GB SSD  Intel Iris Plus Graphics 650       macOS
# 5    4.0            500GB HDD                 AMD Radeon R5  Windows 10
# 6   16.0  256GB Flash Storage       Intel Iris Pro Graphics    Mac OS X
# 7    8.0  256GB Flash Storage        Intel HD Graphics 6000       macOS
# 8   16.0            512GB SSD          Nvidia GeForce MX150  Windows 10
# 9    8.0            256GB SSD        Intel UHD Graphics 620  Windows 10
# 10   4.0            500GB HDD         Intel HD Graphics 620       No OS
# 11   4.0            500GB HDD         Intel HD Graphics 520       No OS
# 12  16.0            256GB SSD            AMD Radeon Pro 555       macOS
# 13   4.0            256GB SSD            AMD Radeon R5 M430  Windows 10
# 14   8.0            256GB SSD         Intel HD Graphics 615       macOS
# 15   8.0            256GB SSD  Intel Iris Plus Graphics 640       macOS
# 16   8.0            256GB SSD            AMD Radeon R5 M430  Windows 10
# 17  16.0            512GB SSD            AMD Radeon Pro 560       macOS
# 18   8.0              1TB HDD          Nvidia GeForce 940MX       No OS
# 19   8.0            128GB SSD        Intel UHD Graphics 620  Windows 10
#
#     Weight        Price  Lable_Company  Lable_OpSys  Lable_TypeName
# 0     1.37   71378.6832              1            8               4
# 1     1.34   47895.5232              1            8               4
# 2     1.86   30636.0000              7            4               3
# 3     1.83  135195.3360              1            8               4
# 4     1.37   96095.8080              1            8               4
# 5     2.10   21312.0000              0            5               3
# 6     2.04  114017.6016              1            3               4
# 7     1.34   61735.5360              1            8               4
# 8     1.30   79653.6000              2            5               4
# 9     1.60   41025.6000              0            5               4
# 10    1.86   20986.9920              7            4               3
# 11    1.86   18381.0672              7            4               3
# 12    1.83  130001.6016              1            8               4
# 13    2.20   26581.3920              4            5               3
# 14    0.92   67260.6720              1            8               4
# 15    1.37   80908.3440              1            8               4
# 16    2.20   39693.6000              4            5               3
# 17    1.83  152274.2400              1            8               4
# 18    2.20   26586.7200             10            4               3
# 19    1.22   52161.1200              4            5               4

# %%
Data.isnull().sum()
# Out:
# Labtop_ID           0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Lable_Company       0
# Lable_OpSys         0
# Lable_TypeName      0
# dtype: int64

# %%
i3 = np.array(Data["Cpu"][Data["Cpu"].str.contains("i3")])
i5 = np.array(Data["Cpu"][Data["Cpu"].str.contains("i5")])
i7 = np.array(Data["Cpu"][Data["Cpu"].str.contains("i7")])

# %%
Data["Cpu"].replace(i3,"i3",inplace=True)
Data["Cpu"].replace(i5,"i5",inplace=True)
Data["Cpu"].replace(i7,"i7",inplace=True)

# %%
Data["Cpu"].replace(i9,"i9",inplace=True)

# %%
Data["Cpu"].value_counts().sort_values(ascending=False)
# Out:
# Cpu
# i7    513
# i5    410
# i9    214
# i3    134
# Name: count, dtype: int64

# %%
Lable_Cpu_type = Label.fit_transform(Data["Cpu"])
Data["Lable_Cpu_type"] = Lable_Cpu_type

# %%
Features = ["Lable_Company","Lable_TypeName","Lable_Cpu_type","Lable_OpSys","Weight","Ram","Inches"]
x = Data[Features]
y = Data["Price"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,train_size=0.25)

# %%
Model_LR = LinearRegression(positive=True)
Model_DT = DecisionTreeRegressor()
Model_SVR = SVR()

# %%
Model_LR.fit(X_train,Y_train)
# Out:
# LinearRegression(positive=True)

# %%
Model_DT.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
Model_SVR.fit(X_train,Y_train)
# Out:
# SVR()

# %%
print("The last score before add cpu type of Linear Regression model are : ",Model_LR.score(X_test,Y_test)*100)
print("The last score before add cpu type of Decision Tree Regressor model are : ",Model_DT.score(X_test,Y_test)*100)
print("The last score before add cpu type of SVR are :",Model_SVR.score(X_test,Y_test)*100)
# Out:
# The score of Linear Regression model are :  49.651570162647005
# The score of Decision Tree Regressor model are :  47.633518879186255
# The score of SVR are : -13.740857497664738

# %%
print("The last score after add cpu type of Linear Regression model are : ",Model_LR.score(X_test,Y_test)*100)
print("The last score after add cpu type of Decision Tree Regressor model are : ",Model_DT.score(X_test,Y_test)*100)
print("The last score after add cpu type of SVR are :",Model_SVR.score(X_test,Y_test)*100)
# Out:
# The last score after add cpu type of Linear Regression model are :  52.12011203456621
# The last score after add cpu type of Decision Tree Regressor model are :  52.40762186665453
# The last score after add cpu type of SVR are : -7.35299919215302
